# %%
import json
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import timedelta
from datetime import date

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import seaborn as sns

# Linear Regression to verify implementation
from sklearn.linear_model import LinearRegression
from sklearn.utils import resample

# Scipy for statistics
import scipy

# PyMC3 for Bayesian Inference
import pymc3 as pm

# %matplotlib inline

# %% [markdown]
# ## 1. Populate Dataframes

# %%
# read from csv files
 
topicsDF = pd.read_csv(r'topics.csv',encoding='latin-1')

wf_twitterDF = pd.read_csv(r'twitter_wf_textblob - manual_update.csv',encoding='latin-1')
sap_twitterDF = pd.read_csv(r'twitter_sap_textblob - manual_update.csv',encoding='latin-1')

# %%
# Total number for each company
print("WF Tweets: "+ str(wf_twitterDF.size))

print("SAP Tweets: "+ str(sap_twitterDF.size))
# Out:
# WF Tweets: 11388
# SAP Tweets: 13624

# %%
wf_twitterDF['sourceDate'] = wf_twitterDF['sourceDate'].astype('datetime64[ns]')

# %%
wf_twitterDF.reset_index(drop=True)
wf_twitterDF.set_index('sourceDate')
# Out:
#             Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  \
# sourceDate
# 2019-09-29         213           255             255
# 2019-09-28         154           189             189
# 2019-09-27          45            49              49
# 2019-09-27           0             0               0
# 2019-09-28         175           211             211
# 2019-10-01         360           426             426
# 2019-09-30         291           348             348
# 2019-10-01         396           474             474
# 2019-10-01         413           491             491
# 2019-09-30         298           355             355
# 2019-09-29         192           229             229
# 2019-09-29         237           281             281
# 2019-10-01         400           478             478
# 2019-09-30         347           412             412
# 2019-09-27          52            56              56
# 2019-09-28         179           215             215
# 2019-09-27          17            17              17
# 2019-09-27          49            53              53
# 2019-09-27          58            62              62
# 2019-09-27           6             6               6
# 2019-09-27          61            65              65
# 2019-09-30         331           394             394
# 2019-10-01         406           484             484
# 2019-09-28         161           196             196
# 2019-09-28         191           228             228
# 2019-09-29         217           260             260
# 2019-09-29         265           313             313
# 2019-09-30         286           343             343
# 2019-09-30         287           344             344
# 2019-09-30         332           395             395
# ...                ...           ...             ...
# 2019-09-29         248           292             292
# 2019-09-30         274           327             327
# 2019-10-01         370           441             441
# 2019-10-01         355           421             421
# 2019-10-01         381           458             458
# 2019-09-30         345           410             410
# 2019-09-27          81            86              86
# 2019-09-28         145           180             180
# 2019-09-28         147           182             182
# 2019-09-27          66            70              70
# 2019-09-27          94            99              99
# 2019-09-27          47            51              51
# 2019-09-28         112           142             142
# 2019-09-28         119           151             151
# 2019-09-28         131           166             166
# 2019-09-28         132           167             167
# 2019-09-29         232           276             276
# 2019-09-30         339           403             403
# 2019-09-30         280           337             337
# 2019-09-30         306           367             367
# 2019-09-30         307           369             369
# 2019-09-30         275           332             332
# 2019-09-29         228           272             272
# 2019-09-28         174           210             210
# 2019-09-28         176           212             212
# 2019-09-27          62            66              66
# 2019-09-29         216           259             259
# 2019-09-28         136           171             171
# 2019-09-27          68            73              73
# 2019-09-30         302           361             361
#
#                                   id  \
# sourceDate
# 2019-09-29  5dae74f611bb5a25b06906f2
# 2019-09-28  5dae74ce11bb5a25b06906b0
# 2019-09-27  5dab73cd11bb5a1f6c86dfee
# 2019-09-27  5dab73ca11bb5a1f6c86dfbd
# 2019-09-28  5dae74d011bb5a25b06906c6
# 2019-09-28                      NaN  9/28/2019 20:53           0           0
# 2019-09-28                      NaN  9/28/2019 19:59           0           0
# 2019-09-28                      NaN  9/28/2019 18:06           0           0
# 2019-09-28  https://t.co/XQYupf1Ija  9/28/2019 18:06           1           2
# 2019-09-29                      NaN  9/29/2019 11:24           0           0
# 2019-09-30  https://t.co/7O2640dfdf  9/30/2019 14:36           0           0
# 2019-09-30                      NaN  9/30/2019 20:02           0           0
# 2019-09-30                      NaN  9/30/2019 16:47           0           0
# 2019-09-30  https://t.co/0vTzot1Q0T  9/30/2019 16:39           0           0
# 2019-09-30                      NaN  9/30/2019 20:25           0           0
# 2019-09-29  https://t.co/PWwFqxKN0E  9/29/2019 13:01           0           0
# 2019-09-28  https://t.co/aTmkBLUdgn  9/28/2019 14:22           0           0
# 2019-09-28  https://t.co/aTmkBLUdgn  9/28/2019 14:15           1           0
# 2019-09-27                      NaN  9/27/2019 22:17           0           0
# 2019-09-29                      NaN  9/29/2019 16:56           0           0
# 2019-09-28  https://t.co/iCxCeH4zh4  9/28/2019 17:57           0           0
# 2019-09-27  https://t.co/X56GUKqD26  9/27/2019 22:10           0           0
# 2019-09-30  https://t.co/lWnn2JC6U7  9/30/2019 17:34           0           1
#
#             retweetCount  ...  lang  isRelated source   NP  isInReplyTo  \
# sourceDate                ...
# 2019-09-29             0  ...    en          Y     WF    N            0
# 2019-09-28             0  ...    en          Y     WF    N            0
# 2019-09-27             0  ...    en          Y     WF  NaN            0
# 2019-09-27             0  ...    en          Y     WF  NaN            0
# 2019-09-28             0  ...    en          Y     WF  NaN            0
# 2019-10-01             0  ...    en          Y     WF    N            0
# 2019-09-30             0  ...    es          Y     WF  NaN            0
# 2019-10-01             0  ...    es          Y     WF  NaN            0
# 2019-10-01             0  ...    es          Y     WF  NaN            0
# 2019-09-30             3  ...    es          Y     WF  NaN            0
# 2019-09-29             0  ...    en          Y     WF    N            0
# 2019-09-29             0  ...    en          Y     WF  NaN            0
# 2019-10-01             0  ...    en          Y     WF  NaN            0
# 2019-09-30             0  ...    en          Y     WF    N            0
# 2019-09-27             0  ...    en          Y     WF  NaN            0
# 2019-09-28             0  ...    en          Y     WF  NaN            0
# 2019-09-27             0  ...    en          Y     WF  NaN            0
# 2019-09-27             0  ...    en          Y     WF  NaN            0
# 2019-09-27             0  ...    en          Y     WF  NaN            0
# 2019-09-27             2  ...    en          Y     WF  NaN            0
# 2019-09-27             3  ...    en          Y     WF  NaN            0
# 2019-09-30             0  ...    en          Y     WF  NaN            0
# 2019-10-01             0  ...    en          Y     WF  NaN            0
# 2019-09-28             0  ...    en          Y     WF  NaN            0
# 2019-09-28             0  ...    en          Y     WF  NaN            0
# 2019-09-29             0  ...    en          Y     WF  NaN            0
# 2019-09-29             1  ...    en          Y     WF  NaN            0
# 2019-09-30             0  ...    en          Y     WF  NaN            0
# 2019-09-30             0  ...    en          Y     WF  NaN            0
# 2019-09-30             1  ...    en          Y     WF  NaN            0
# ...                  ...  ...   ...        ...    ...  ...          ...
# 2019-09-29             0  ...    en          Y     WF  NaN            0
# 2019-09-30             0  ...    en          Y     WF  NaN            0
# 2019-10-01             0  ...    en          Y     WF  NaN            0
# 2019-10-01             0  ...    en          Y     WF  NaN            0
# 2019-10-01             0  ...    en          Y     WF  NaN            0
# 2019-09-30             0  ...    en          Y     WF  NaN            0
# 2019-09-27             0  ...    en          Y     WF  NaN            0
# 2019-09-28             0  ...    en          Y     WF    N            0
# 2019-09-28             0  ...    en          Y     WF    N            0
# 2019-09-27             0  ...    en          Y     WF  NaN            0
# 2019-09-27             0  ...    en          Y     WF  NaN            0
# 2019-09-27             0  ...    en          Y     WF  NaN            0
# 2019-09-28             0  ...    en          Y     WF    P            0
# 2019-09-28             0  ...    en          Y     WF    P            0
# 2019-09-28             0  ...    en          Y     WF    P            0
# 2019-09-28             7  ...    en          Y     WF    P            0
# 2019-09-29             0  ...    en          Y     WF    P            0
# 2019-09-30             0  ...    en          Y     WF  NaN            0
# 2019-09-30             0  ...    en          Y     WF    N            0
# 2019-09-30             0  ...    en          Y     WF    N            0
# 2019-09-30             2  ...    en          Y     WF    N            0
# 2019-09-30             0  ...    en          Y     WF    N            0
# 2019-09-29             0  ...    en          Y     WF    P            0
# 2019-09-28             0  ...    en          Y     WF  NaN            0
# 2019-09-28             1  ...    en          Y     WF  NaN            0
# 2019-09-27             0  ...    en          Y     WF    P            0
# 2019-09-29             0  ...    en          Y     WF    P            0
# 2019-09-28             0  ...    en          Y     WF    P            0
# 2019-09-27             0  ...    en          Y     WF    P            0
# 2019-09-30             0  ...    en          Y     WF  NaN            0
#
#                  user_id vader_compound vader_sentiment tb_polarity  \
# 2019-09-30  1.140000e+18         0.6808               P    0.281481
# 2019-09-29  2.309282e+07         0.6908               P    0.568182
# 2019-09-28  3.939407e+07         0.7003               P    0.000000
# 2019-09-28  1.762247e+07         0.7003               P    0.000000
# 2019-09-27  1.257184e+08         0.7096               P    0.136364
# 2019-09-29  4.880417e+09         0.7096               P    0.136364
# 2019-09-28  1.890639e+07         0.7184               P    0.700000
# 2019-09-27  3.513041e+08         0.7269               P    0.800000
# 2019-09-30  1.372023e+09         0.8126               P    0.166667
#
#             tb_sentiment
# sourceDate
# 2019-09-29             E
# 2019-09-28             E
# 2019-09-27             E
# 2019-09-27             E
# 2019-09-28             E
# 2019-10-01             E
# 2019-09-30             E
# 2019-10-01             E
# 2019-10-01             E
# 2019-09-30             E
# 2019-09-29             E
# 2019-09-29             E
# 2019-10-01             E
# 2019-09-30             E
# 2019-09-27             E
# 2019-09-28             E
# 2019-09-27             E
# 2019-09-27             E
# 2019-09-27             E
# 2019-09-27             E
# 2019-09-27             E
# 2019-09-30             E
# 2019-10-01             E
# 2019-09-28             E
# 2019-09-28             E
# 2019-09-29             E
# 2019-09-29             E
# 2019-09-30             E
# 2019-09-30             E
# 2019-09-30             E
# ...                  ...
# 2019-09-29             E
# 2019-09-30             E
# 2019-10-01             E
# 2019-10-01             E
# 2019-10-01             E
# 2019-09-30             E
# 2019-09-27             E
# 2019-09-28             E
# 2019-09-28             E
# 2019-09-27             E
# 2019-09-27             E
# 2019-09-27             E
# 2019-09-28             E
# 2019-09-28             E
# 2019-09-28             E
# 2019-09-28             E
# 2019-09-29             E
# 2019-09-30             E
# 2019-09-30             E
# 2019-09-30             E
# 2019-09-30             E
# 2019-09-30             E
# 2019-09-29             P
# 2019-09-28             E
# 2019-09-28             E
# 2019-09-27             E
# 2019-09-29             E
# 2019-09-28             P
# 2019-09-27             P
# 2019-09-30             E
#
# [438 rows x 25 columns]

# %%
sap_twitterDF['sourceDate'] = sap_twitterDF['sourceDate'].astype('datetime64[ns]')

# %%
sap_twitterDF.reset_index(drop=True)
sap_twitterDF.set_index('sourceDate')
# Out:
#             Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  \
# sourceDate
# 2019-10-09           0           619             619
# 2019-10-09           1           621             621
# 2019-10-09           2           633             633
# 2019-10-09           3           643             643
# 2019-10-10           4           645             645
# 2019-10-10           5           646             646
# 2019-10-10           6           647             647
# 2019-10-10           7           648             648
# 2019-10-10           8           649             649
# 2019-10-10           9           650             650
# 2019-10-10          10           651             651
# 2019-10-10          11           652             652
# 2019-10-10          12           653             653
# 2019-10-10          13           654             654
# 2019-10-10          14           655             655
# 2019-10-10          15           656             656
# 2019-10-10          16           657             657
# 2019-10-10          17           658             658
# 2019-10-10          18           659             659
# 2019-10-10          19           660             660
# 2019-10-10          20           661             661
# 2019-10-10          21           662             662
# 2019-10-10          22           663             663
# 2019-10-10          23           664             664
# 2019-10-10          24           665             665
# 2019-10-10          25           666             666
# 2019-10-10          26           667             667
# 2019-10-10          27           668             668
# 2019-10-10          28           669             669
# 2019-10-10          29           670             670
# ...                ...           ...             ...
# 2019-10-15         494          1244            1244
# 2019-10-16         495          1245            1245
# 2019-10-16         496          1246            1246
# 2019-10-16         497          1248            1248
# 2019-10-16         498          1251            1251
# 2019-10-16         499          1252            1252
# 2019-10-16         500          1253            1253
# 2019-10-16         501          1255            1255
# 2019-10-16         502          1256            1256
# 2019-10-16         503          1264            1264
# 2019-10-16         504          1265            1265
# 2019-10-16         505          1266            1266
# 2019-10-16         506          1268            1268
# 2019-10-16         507          1269            1269
# 2019-10-09  Experience Management: "Start with empathy for...
# 2019-10-09  Experience Management: "Start with empathy for...
# 2019-10-09  SAP CEO  has made clear: the new economy is he...
# 2019-10-09  Thanks  for hosting Bill Mcdermott CEO of SAP ...
# 2019-10-10  New article: "SAP CEO Bill McDermott stepping ...
# 2019-10-10  Breaking News:  CEO Bill McDermott Resigns; Mo...
# 2019-10-10  Sad but happy to offer a sincere thank you to ...
# 2019-10-10  SAP said CEO Bill McDermott wouldnÃÂ¢ÃÂÃÂ...
# 2019-10-10  Bill McDermott steps down as SAPÃÂ¢ÃÂÃÂs ...
# 2019-10-10  After 17 years at SAP,  is stepping down from ...
# 2019-10-10  Interesting Development.\nQuestion Everything....
# 2019-10-10  SAP said CEO Bill McDermott wouldnÃÂ¢ÃÂÃÂ...
# 2019-10-10  Interesting Development.\nQuestion Everything....
# 2019-10-10  SAP said CEO Bill McDermott wouldnÃÂ¢ÃÂÃÂ...
# 2019-10-10  SAP CEO Bill McDermott steps down; shares rise...
# 2019-10-10  Bill McDermott steps down as SAPÃÂ¢ÃÂÃÂs ...
# 2019-10-10  Bill McDermott steps down as SAPÃÂ¢ÃÂÃÂs ...
# 2019-10-10  SAP said CEO Bill McDermott wouldnÃÂ¢ÃÂÃÂ...
# 2019-10-10  Interesting Development.\nQuestion Everything....
# 2019-10-10  SAP CEO Bill McDermott to step down, pre-annou...
# 2019-10-10  Interesting Development.\nQuestion Everything....
# 2019-10-10  After  steps Back from being CEO of   and   wh...
# 2019-10-10  Bill McDermott steps down as SAPÃÂ¢ÃÂÃÂsÃ...
# 2019-10-10                            SAP CEO steps down\n \n
# 2019-10-10  Bill McDermott steps down as SAPÃÂ¢ÃÂÃÂs ...
# 2019-10-10  Wow - Bill McDermott (ÃÂ¢ÃÂÃÂ¦)ÃÂ¢ÃÂÃÂ...
# 2019-10-10  Bill McDermott steps down as SAPÃÂ¢ÃÂÃÂs ...
# 2019-10-10  SAP said CEO Bill McDermott wouldnÃÂ¢ÃÂÃÂ...
# 2019-10-10  Bill McDermott steps down as SAPÃÂ¢ÃÂÃÂs ...
# 2019-10-10  Interesting Development.\nQuestion Everything....
# ...                                                       ...
# 2019-10-15  SAPÃÂ£ÃÂÃÂ®ÃÂ£ÃÂÃÂÃÂ£ÃÂÃÂ¯ÃÂ£ÃÂ...
# 2019-10-16  SAP CEO Bill McDermott stepping down after ove...
# 2019-10-16  Bill McDermott steps down as SAPÃÂ¢ÃÂÃÂs ...
# 2019-10-16  RT  Quick Take on   CEO Bill McDermott's move ...
# 2019-10-16  Happy boss day, to best one in the world! \n  ...
# 2019-10-16  A sorpresa McDermott lascia , cosÃÂÃÂ¬ come...
# 2019-10-16          : El  de , Bill McDermott, renuncia\n cc
# 2019-10-16          : El  de , Bill McDermott, renuncia\n cc
# 2019-10-16  .@BillRMcDermott stepped down as  CEO effectiv...
# 2019-10-16  This is a very inciteful interview of outgoing...
# 2019-10-16  A sorpresa McDermott lascia , cosÃÂÃÂ¬ come...
# 2019-10-16            CEO of SAP Bill McDermott resigns  via
# 2019-10-16  After 17 years at SAP,  is stepping down from ...
# 2019-10-16  Congrats 2  for naming  as 1st woman CEO of a ...
# 2019-10-16  In a surprise, SAP CEO Bill McDermott steps do...
# 2019-10-16  After 17 years at SAP,  is stepping down from ...
# 2019-10-16  A surprise call with outgoing  CEO Bill McDerm...
# 2019-10-16  A sorpresa McDermott lascia , cosÃÂÃÂ¬ come...
# 2019-10-16  SAP ÃÂ«ÃÂ¹ÃÂ ÃÂ«ÃÂ§ÃÂ¥ÃÂ«ÃÂÃÂÃÂ«Ã...
# 2019-10-16  A sorpresa McDermott lascia , cosÃÂÃÂ¬ come...
# 2019-10-16  A sorpresa McDermott lascia , cosÃÂÃÂ¬ come...
# 2019-10-16  A sorpresa McDermott lascia , cosÃÂÃÂ¬ come...
# 2019-10-16  Incredible news and big statement of intent. S...
# 2019-10-16  Every CEO dreams of handing an exceptionally s...
# 2019-10-16  ItÃÂ¢ÃÂÃÂs been a very exciting 36 hours....
# 2019-10-16  SAPÃÂ¢ÃÂÃÂs Bill McDermott on stepping do...
# 2019-10-16  In a surprise,  CEO Bill McDermott steps down ...
# 2019-10-16                          - CEO de SAP se despide
# 2019-10-16  Every CEO dreams of handing an exceptionally s...
# 2019-10-16  Great news: last week we made history as  beca...
#
#                                 URL     createdTimestamp  quoteCount  \
# sourceDate
# 2019-10-09                      NaN  2019-10-09 18:10:03           0
# 2019-10-09  https://t.co/t0MxMZ5DxI  2019-10-09 18:00:01           0
# 2019-10-09  https://t.co/tqPgEZix2U  2019-10-09 14:36:00           0
# 2019-10-09                      NaN  2019-10-09 05:21:42           0
# 2019-10
E
# 2019-10-10   -0.155556             E
# 2019-10-10   -0.155556             E
# 2019-10-10   -0.155556             E
# 2019-10-10    0.026936             E
# 2019-10-10   -0.155556             E
# 2019-10-10   -0.243056             E
# 2019-10-10   -0.155556             E
# 2019-10-10    0.172222             E
# ...                ...           ...
# 2019-10-15    0.000000             E
# 2019-10-16   -0.155556             E
# 2019-10-16   -0.077778             E
# 2019-10-16    0.333333             E
# 2019-10-16    0.900000             P
# 2019-10-16   -0.125000             E
# 2019-10-16    0.000000             E
# 2019-10-16    0.000000             E
# 2019-10-16    0.222222             E
# 2019-10-16    0.168182             E
# 2019-10-16   -0.125000             E
# 2019-10-16    0.000000             E
# 2019-10-16   -0.155556             E
# 2019-10-16    0.031250             E
# 2019-10-16   -0.155556             E
# 2019-10-16   -0.155556             E
# 2019-10-16    0.000000             E
# 2019-10-16   -0.125000             E
# 2019-10-16    0.000000             E
# 2019-10-16   -0.125000             E
# 2019-10-16   -0.125000             E
# 2019-10-16   -0.125000             E
# 2019-10-16    0.300000             E
# 2019-10-16    0.311111             E
# 2019-10-16    0.595000             P
# 2019-10-16   -0.155556             E
# 2019-10-16   -0.155556             E
# 2019-10-16    0.000000             E
# 2019-10-16    0.311111             E
# 2019-10-16    0.400000             E
#
# [524 rows x 25 columns]

# %%
# Weight the vader compound and tb_polarity data by quote, reply and retweet count. 

wf_twitterDF['vader_weighted'] = wf_twitterDF.apply(lambda row: row.vader_compound * (1 + row.favoriteCount + row.quoteCount + row.replyCount + row.retweetCount), axis = 1) 
wf_twitterDF['tb_weighted'] = wf_twitterDF.apply(lambda row: row.tb_polarity * (1 + row.favoriteCount + row.quoteCount + row.replyCount + row.retweetCount), axis = 1)

# %%
# Weight the vader compound and tb_polarity data by quote, reply and retweet count. 

sap_twitterDF['vader_weighted'] = sap_twitterDF.apply(lambda row: row.vader_compound * (1 + row.favoriteCount + row.quoteCount + row.replyCount + row.retweetCount), axis = 1) 
sap_twitterDF['tb_weighted'] = sap_twitterDF.apply(lambda row: row.tb_polarity * (1 + row.favoriteCount + row.quoteCount + row.replyCount + row.retweetCount), axis = 1)

# %% [markdown]
# ### 1.2 Join with Stock price

# %%
# read from csv files
 
WF_stock = pd.read_csv(r'./Stock_Price/wFC_limited.csv',encoding='latin-1')
WF_stock['Date'] = WF_stock['Date'].astype('datetime64[ns]') 

WF_stock.reset_index(drop=True)
WF_stock.set_index('Date') 

WF_stock.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 2019-09-25  48.730000  49.540001  48.650002  49.259998  48.793034  21313100
# 1 2019-09-26  49.250000  49.369999  48.820000  48.869999  48.406731  19984000
# 2 2019-09-27  50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 3 2019-09-30  50.770000  50.849998  50.060001  50.439999  49.961849  26897100
# 4 2019-10-01  50.650002  50.779999  49.000000  49.060001  48.594933  27249300

# %%
SAP_stock = pd.read_csv(r'./Stock_Price/SAP_limited.csv',encoding='latin-1')
SAP_stock['Date'] = SAP_stock['Date'].astype('datetime64[ns]') 

SAP_stock.reset_index(drop=True)
SAP_stock.set_index('Date') 

SAP_stock.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2019-10-09  115.849998  116.739998  115.580002  116.050003  116.050003
# 1 2019-10-10  114.959999  116.160004  114.559998  115.250000  115.250000
# 2 2019-10-11  125.720001  127.900002  125.470001  126.199997  126.199997
# 3 2019-10-14  125.940002  126.559998  125.739998  126.050003  126.050003
# 4 2019-10-15  125.830002  127.889999  125.470001  127.180000  127.180000
#
#     Volume
# 0  1061600
# 1  1062100
# 2  2234300
# 3   877700
# 4   830900

# %%
# join tables by sourceDate and Date
result = pd.merge(wf_twitterDF, WF_stock, left_on='sourceDate', right_on='Date') # how='right', 
wf_twitterDF = result
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1
# 243             0  ...             E          0.0000    0.000000 2019-09-26
# 244             0  ...             E          0.0000   -0.066667 2019-09-26
# 245             1  ...             E          0.0000   -0.208333 2019-09-26
# 246             0  ...             E          0.7500    0.450000 2019-09-26
# 247             0  ...             E          0.2500   -0.083333 2019-09-26
# 248             1  ...             E          0.7500   -0.250000 2019-09-26
# 249             0  ...             E          0.2500   -0.083333 2019-09-26
# 250             0  ...             E          0.0772    0.000000 2019-10-02
# 251             0  ...             E          0.2500    0.018182 2019-10-02
# 252             0  ...             E          0.2500    0.211039 2019-10-02
# 253             0  ...             E          0.5000   -0.200000 2019-10-02
# 254             0  ...             E          0.2500    0.000000 2019-10-02
# 255             0  ...             E          0.2500    0.012121 2019-10-02
# 256             0  ...             E          0.2500    0.012121 2019-10-02
# 257             0  ...             E          0.2500    0.012121 2019-10-02
# 258             0  ...             E          0.2500    0.018182 2019-10-02
# 259             0  ...             E          0.2500    0.018182 2019-10-02
# 260             0  ...             E          0.2500    0.018182 2019-10-02
# 261             0  ...             E          0.2500    0.018182 2019-10-02
# 262             3  ...             E          3.5000    0.254545 2019-10-02
# 263             0  ...             E          0.2500    0.018182 2019-10-02
# 264             0  ...             E          0.2500    0.018182 2019-10-02
# 265             0  ...             E          0.2500    0.018182 2019-10-02
# 266             0  ...             E          0.5000    0.036364 2019-10-02
# 267             0  ...             E          0.2500   -0.331818 2019-10-02
# 268             0  ...             E          0.2500    0.136364 2019-10-02
# 269             0  ...             E          0.4588    0.055682 2019-10-02
#
#           Open       High        Low      Close  Adj Close    Volume
# 0    50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 1    50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 2    50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 3    50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 4    50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 5    50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 6    50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 7    50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 8    50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 9    50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 10   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 11   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 12   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 13   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 14   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 15   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 16   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 17   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 18   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 19   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 20   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 21   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 22   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 23   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 24   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 25   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 26   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 27   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 28   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# 29   50.400002  51.410000  50.250000  50.709999  50.229290  59467400
# ..         ...        ...        ...        ...        ...       ...
# 240  50.770000  50.849998  50.060001  50.439999  49.961849  26897100
# 241  50.770000  50.849998  50.060001  50.439999  49.961849  26897100
# 242  48.730000  49.540001  48.650002  49.259998  48.793034  21313100
# 243  49.250000  49.369999  48.820000  48.869999  48.406731  19984000
# 244  49.250000  49.369999  48.820000  48.869999  48.406731  19984000
# 245  49.250000  49.369999  48.820000  48.869999  48.406731  19984000
# 246  49.250000  49.369999  48.820000  48.869999  48.406731  19984000
# 247  49.250000  49.369999  48.820000  48.869999  48.406731  19984000
# 248  49.250000  49.369999  48.820000  48.869999  48.406731  19984000
# 249  49.250000  49.369999  48.820000  48.869999  48.406731  19984000
# 250  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
# 251  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
# 252  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
# 253  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
# 254  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
# 255  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
# 256  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
# 257  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
# 258  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
# 259  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
# 260  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
# 261  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
# 262  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
# 263  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
# 264  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
# 265  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
# 266  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
# 267  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
# 268  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
# 269  48.720001  49.040001  48.369999  48.470001  48.010525  23515900
#
# [270 rows x 35 columns]

# %%
# join tables by sourceDate and Date
result = pd.merge(sap_twitterDF, SAP_stock, left_on='sourceDate', right_on='Date') # how='right', 
sap_twitterDF = result

# %%
sap_twitterDF.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                        id  \
# 0           0           619             619  5dae77e811bb5a25b069085e
# 1           1           621             621  5dae77e811bb5a25b0690860
# 2           2           633             633  5dae77e911bb5a25b069086c
# 3           3           643             643  5dae77e911bb5a25b0690876
# 4           4           645             645  5dae784011bb5a25b0690878
#
#                                                 text                      URL  \
# 0  Experience Management: "Start with empathy for...                      NaN
# 1  Experience Management: "Start with empathy for...  https://t.co/t0MxMZ5DxI
# 2  SAP CEO  has made clear: the new economy is he...  https://t.co/tqPgEZix2U
# 3  Thanks  for hosting Bill Mcdermott CEO of SAP ...                      NaN
# 4  New article: "SAP CEO Bill McDermott stepping ...  https://t.co/DoQvIY7sVy
#
#       createdTimestamp  quoteCount  replyCount  retweetCount  ...  \
# 0  2019-10-09 18:10:03           0           0             0  ...
# 1  2019-10-09 18:00:01           0           0             2  ...
# 2  2019-10-09 14:36:00           0           0             0  ...
# 3  2019-10-09 05:21:42           0           0             0  ...
# 4  2019-10-10 23:58:48           0           0             0  ...
#
#    tb_sentiment  vader_weighted tb_weighted       Date        Open  \
# 0             E          0.0000    0.000000 2019-10-09  115.849998
# 1             E          0.0000    0.000000 2019-10-09  115.849998
# 2             E          0.1027    0.078788 2019-10-09  115.849998
# 3             E          1.4368    0.400000 2019-10-09  115.849998
# 4             E          0.0000   -0.012795 2019-10-10  114.959999
#
#          High         Low       Close   Adj Close   Volume
# 0  116.739998  115.580002  116.050003  116.050003  1061600
# 1  116.739998  115.580002  116.050003  116.050003  1061600
# 2  116.739998  115.580002  116.050003  116.050003  1061600
# 3  116.739998  115.580002  116.050003  116.050003  1061600
# 4  116.160004  114.559998  115.250000  115.250000  1062100
#
# [5 rows x 35 columns]

# %% [markdown]
# ### 1.5 Bootstrap data - 500 samples per day

# %%
def bootstrap_replicate(data, num_samples, rand_state):
    return resample(data, replace=True, n_samples=num_samples, random_state=rand_state)

number_of_samples =500
rand_state=5

# WF

source_date = '2019-09-25'
wf_vader_0925 = bootstrap_replicate(wf_twitterDF[wf_twitterDF['sourceDate'].dt.date.astype(str) == source_date], number_of_samples, rand_state)

source_date = '2019-09-26'
wf_vader_0926 = bootstrap_replicate(wf_twitterDF[wf_twitterDF['sourceDate'].dt.date.astype(str) == source_date], number_of_samples, rand_state)

source_date = '2019-09-27'
wf_vader_0927 = bootstrap_replicate(wf_twitterDF[wf_twitterDF['sourceDate'].dt.date.astype(str) == source_date], number_of_samples, rand_state)

#source_date = '2019-09-28'
#wf_vader_0928 = bootstrap_replicate(wf_twitterDF[wf_twitterDF['sourceDate'].dt.date.astype(str) == source_date], number_of_samples, rand_state)

#source_date = '2019-09-29'
#wf_vader_0929 = bootstrap_replicate(wf_twitterDF[wf_twitterDF['sourceDate'].dt.date.astype(str) == source_date], number_of_samples, rand_state)

source_date = '2019-09-30'
wf_vader_0930 = bootstrap_replicate(wf_twitterDF[wf_twitterDF['sourceDate'].dt.date.astype(str) == source_date], number_of_samples, rand_state)

source_date = '2019-10-01'
wf_vader_1001 = bootstrap_replicate(wf_twitterDF[wf_twitterDF['sourceDate'].dt.date.astype(str) == source_date], number_of_samples, rand_state)

source_date = '2019-10-02'
wf_vader_1002 = bootstrap_replicate(wf_twitterDF[wf_twitterDF['sourceDate'].dt.date.astype(str) == source_date], number_of_samples, rand_state)

#wf_t_master_df= pd.concat([wf_vader_0925, wf_vader_0926, wf_vader_0927, wf_vader_0928, wf_vader_0929, wf_vader_0930, wf_vader_1001, wf_vader_1002], ignore_index=True)
wf_t_master_df= pd.concat([wf_vader_0925, wf_vader_0926, wf_vader_0927, wf_vader_0930, wf_vader_1001, wf_vader_1002], ignore_index=True)

# %%
wf_t_master_df.reset_index(drop=True)
wf_t_master_df.set_index('sourceDate')
# Out:
#             Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  \
# sourceDate
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# 2019-09-25          95           109             109
# ...                ...           ...             ...
# 2019-10-02         418           502             502
# 2019-10-02         419           504             504
# 2019-10-02         431           527             527
# 2019-10-02         418           502             502
# 2019-10-02         433           529             529
# 2019-10-02         436           534             534
# 2019-10-02         426           516             516
# 2019-10-02         419           504             504
# 2019-10-02         431           527             527
# 2019-10-02         425           515             515
# 2019-10-02         418           502             502
# 2019-10-02         424           514             514
# 2019-10-02         430           524             524
# 2019-10-02         431           527             527
# 2019-10-02         418           502             502
# 2019-10-02         426           516             516
# 2019-10-02         436           534             534
# 2019-10-02         423           513             513
# 2019-10-02         436           534             534
# 2019-10-02         421           509             509
# 2019-10-02         428           518             518
# 2019-10-02         430           524             524
# 2019-10-02         430           524             524
# 2019-10-02         433           529             529
# 2019-10-02         428           518             518
# 2019-10-02         425           515             515
# 2019-10-02         423           513             513
# 2019-10-02         424           514             514
# 2019-10-02         435           533             533
# 2019-10-02         434           530             530
#
#                                   id  \
# sourceDate
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-09-25  5dae743a11bb5a25b0690660
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
# 2019-10-02  23515900
#
# [3000 rows x 34 columns]

# %%
# SAP
# 10/09/19 - 10/16/19

source_date = '2019-10-09'
sap_vader_1009 = bootstrap_replicate(sap_twitterDF[sap_twitterDF['sourceDate'].dt.date.astype(str) == source_date], number_of_samples, rand_state)

source_date = '2019-10-10'
sap_vader_1010 = bootstrap_replicate(sap_twitterDF[sap_twitterDF['sourceDate'].dt.date.astype(str) == source_date], number_of_samples, rand_state)

source_date = '2019-10-11'
sap_vader_1011 = bootstrap_replicate(sap_twitterDF[sap_twitterDF['sourceDate'].dt.date.astype(str) == source_date], number_of_samples, rand_state)

#source_date = '2019-10-12'
#sap_vader_1012 = bootstrap_replicate(sap_twitterDF[sap_twitterDF['sourceDate'].dt.date.astype(str) == source_date], number_of_samples, rand_state)

#source_date = '2019-10-13'
#sap_vader_1013 = bootstrap_replicate(sap_twitterDF[sap_twitterDF['sourceDate'].dt.date.astype(str) == source_date], number_of_samples, rand_state)

source_date = '2019-10-14'
sap_vader_1014 = bootstrap_replicate(sap_twitterDF[sap_twitterDF['sourceDate'].dt.date.astype(str) == source_date], number_of_samples, rand_state)

source_date = '2019-10-15'
sap_vader_1015 = bootstrap_replicate(sap_twitterDF[sap_twitterDF['sourceDate'].dt.date.astype(str) == source_date], number_of_samples, rand_state)

source_date = '2019-10-16'
sap_vader_1016 = bootstrap_replicate(sap_twitterDF[sap_twitterDF['sourceDate'].dt.date.astype(str) == source_date], number_of_samples, rand_state)

#sap_t_master_df= pd.concat([sap_vader_1009, sap_vader_1010, sap_vader_1011, sap_vader_1012, sap_vader_1013, sap_vader_1014, sap_vader_1015, sap_vader_1016], ignore_index=True)
sap_t_master_df= pd.concat([sap_vader_1009, sap_vader_1010, sap_vader_1011, sap_vader_1014, sap_vader_1015, sap_vader_1016], ignore_index=True)

# %%
sap_t_master_df.reset_index(drop=True)
sap_t_master_df.set_index('sourceDate')
# Out:
#             Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  \
# sourceDate
# 2019-10-09           3           643             643
# 2019-10-09           2           633             633
# 2019-10-09           3           643             643
# 2019-10-09           1           621             621
# 2019-10-09           2           633             633
# 2019-10-09           2           633             633
# 2019-10-09           0           619             619
# 2019-10-09           1           621             621
# 2019-10-09           0           619             619
# 2019-10-09           0           619             619
# 2019-10-09           3           643             643
# 2019-10-09           2           633             633
# 2019-10-09           3           643             643
# 2019-10-09           0           619             619
# 2019-10-09           2           633             633
# 2019-10-09           0           619             619
# 2019-10-09           3           643             643
# 2019-10-09           0           619             619
# 2019-10-09           3           643             643
# 2019-10-09           1           621             621
# 2019-10-09           1           621             621
# 2019-10-09           3           643             643
# 2019-10-09           0           619             619
# 2019-10-09           3           643             643
# 2019-10-09           0           619             619
# 2019-10-09           1           621             621
# 2019-10-09           3           643             643
# 2019-10-09           1           621             621
# 2019-10-09           3           643             643
# 2019-10-09           2           633             633
# ...                ...           ...             ...
# 2019-10-16         505          1266            1266
# 2019-10-16         512          1277            1277
# 2019-10-16         495          1245            1245
# 2019-10-16         520          1288            1288
# 2019-10-16         523          1293            1293
# 2019-10-16         499          1252            1252
# 2019-10-16         509          1273            1273
# 2019-10-16         500          1253            1253
# 2019-10-16         508          1271            1271
# 2019-10-16         514          1279            1279
# 2019-10-16         504          1265            1265
# 2019-10-16         504          1265            1265
# 2019-10-16         500          1253            1253
# 2019-10-16         508          1271            1271
# 2019-10-16         515          1280            1280
# 2019-10-16         496          1246            1246
# 2019-10-16         520          1288            1288
# 2019-10-16         513          1278            1278
# 2019-10-16         495          1245            1245
# 2019-10-16         498          1251            1251
# 2019-10-16         509          1273            1273
# 2019-10-16         508          1271            1271
# 2019-10-16         501          1255            1255
# 2019-10-16         508          1271            1271
# 2019-10-16         518          1286            1286
# 2019-10-16         521          1289            1289
# 2019-10-16         515          1280            1280
# 2019-10-16         498          1251            1251
# 2019-10-16         498          1251            1251
# 2019-10-16         502          1256            1256
#
#                                   id  \
# sourceDate
# 2019-10-09  5dae77e911bb5a25b0690876
# 2019-10-09  5dae77e911bb5a25b069086c
# 2019-10-09  5dae77e911bb5a25b0690876
# 2019-10-09  5dae77e811bb5a25b0690860
# 2019-10-09  5dae77e911bb5a25b069086c
# 2019-10-09  5dae77e911bb5a25b069086c
# 2019-10-09  5dae77e811bb5a25b069085e
# 2019-10-09  5dae77e811bb5a25b0690860
# 2019-10-09  5dae77e811bb5a25b069085e
# 2019-10-09  5dae77e811bb5a25b069085e
# 2019-10-09  5dae77e911bb5a25b0690876
# 2019-10-09  5dae77e911bb5a25b069086c
# 2019-10-09  5dae77e911bb5a25b0690876
# 2019-10-09  5dae77e811bb5a25b069085e
# 2019-10-09  5dae77e911bb5a25b069086c
# 2019-10-09  5dae77e811bb5a25b069085e
# 2019-10-09  5dae77e911bb5a25b0690876
# 2019-10-09  5dae77e811bb5a25b069085e
# 2019-10-09  5dae77e911bb5a25b0690876
# 2019-10-09  5dae77e811bb5a25b0690860
# 2019-10-09  5dae77e811bb5a25b0690860
# 2019-10-09  5dae77e911bb5a25b0690876
# 2019-10-09  5dae77e811bb5a25b069085e
# 2019-10-09  5dae77e911bb5a25b0690876
# 2019-10-09  5dae77e811bb5a25b069085e
# 2019-10-09  5dae77e811bb5a25b0690860
# 2019-10-09  5dae77e911bb5a25b0690876
# 2019-10-09  5dae77
# 2019-10-09           0             0  ...             E          1.4368
# 2019-10-09           0             0  ...             E          0.0000
# 2019-10-09           0             0  ...             E          1.4368
# 2019-10-09           0             2  ...             E          0.0000
# 2019-10-09           0             2  ...             E          0.0000
# 2019-10-09           0             0  ...             E          1.4368
# 2019-10-09           0             0  ...             E          0.0000
# 2019-10-09           0             0  ...             E          1.4368
# 2019-10-09           0             0  ...             E          0.0000
# 2019-10-09           0             2  ...             E          0.0000
# 2019-10-09           0             0  ...             E          1.4368
# 2019-10-09           0             2  ...             E          0.0000
# 2019-10-09           0             0  ...             E          1.4368
# 2019-10-09           0             0  ...             E          0.1027
# ...                ...           ...  ...           ...             ...
# 2019-10-16           0             0  ...             E         -0.6364
# 2019-10-16           0             0  ...             E          0.0000
# 2019-10-16           0             0  ...             E          0.0000
# 2019-10-16           0             0  ...             E          0.2732
# 2019-10-16           0             0  ...             E          0.6249
# 2019-10-16           0             0  ...             E          0.0000
# 2019-10-16           0             0  ...             E          0.2023
# 2019-10-16           0             0  ...             E          0.0000
# 2019-10-16           0             0  ...             E          0.5464
# 2019-10-16           0             0  ...             E          0.0000
# 2019-10-16           0             0  ...             E          0.0000
# 2019-10-16           0             0  ...             E          0.0000
# 2019-10-16           0             0  ...             E          0.0000
# 2019-10-16           0             0  ...             E          0.5464
# 2019-10-16           0             5  ...             E          0.0000
# 2019-10-16           0             0  ...             E          0.0000
# 2019-10-16           0             0  ...             E          0.2732
# 2019-10-16           0             0  ...             E          0.0000
# 2019-10-16           0             0  ...             E          0.0000
# 2019-10-16           0             0  ...             P          1.6956
# 2019-10-16           0             0  ...             E          0.2023
# 2019-10-16           0             0  ...             E          0.5464
# 2019-10-16           0             1  ...             E          0.0000
# 2019-10-16           0             0  ...             E          0.5464
# 2019-10-16           0             0  ...             P          0.8221
# 2019-10-16           0             0  ...             E          0.0000
# 2019-10-16           0             5  ...             E          0.0000
# 2019-10-16           0             0  ...             P          1.6956
# 2019-10-16           0             0  ...             P          1.6956
# 2019-10-16           0             0  ...             E          0.4767
#
#            tb_weighted       Date        Open        High         Low  \
# sourceDate
# 2019-10-09    0.400000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.078788 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.400000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.000000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.078788 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.078788 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.000000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.000000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.000000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.000000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.400000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.078788 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.400000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.000000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.078788 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.000000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.400000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.000000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.400000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.000000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.000000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.400000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.000000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.400000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.000000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.000000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.400000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.000000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.400000 2019-10-09  115.849998  116.739998  115.580002
# 2019-10-09    0.078788 2019-10-09  115.849998  116.739998  115.580002
# ...                ...        ...         ...         ...         ...
# 2019-10-16    0.000000 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16    0.000000 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16   -0.155556 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16   -0.155556 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16    0.400000 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16   -0.125000 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16   -0.155556 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16    0.000000 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16   -0.311111 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16   -0.125000 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16   -0.125000 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16   -0.125000 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16    0.000000 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16   -0.311111 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16   -1.125000 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16   -0.077778 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16   -0.155556 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16   -0.125000 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16   -0.155556 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16    1.800000 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16   -0.155556 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16   -0.311111 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16    0.000000 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16   -0.311111 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16    0.595000 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16    0.000000 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16   -1.125000 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16    1.800000 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16    1.800000 2019-10-16  128.850006  129.279999  128.470001
# 2019-10-16    0.222222 2019-10-16  128.850006  129.279999  128.470001
#
#                  Close   Adj Close   Volume
# sourceDate
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# 2019-10-09  116.050003  116.050003  1061600
# ...                ...         ...      ...
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
# 2019-10-16  128.720001  128.720001  1091500
#
# [3000 rows x 34 columns]

# %% [markdown]
# ## 4. WF - Compare between dates

# %% [markdown]
# ### 4.1. Vader Compound

# %% [markdown]
# #### 4.1.1. Box plot - without resampling

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# Create box plot with Seaborn's default settings
g=sns.boxplot(x='sourceDate', y='vader_weighted', data=wf_twitterDF,  medianprops={'color':'red'}) #, showfliers=False)


# Label the axes
g=plt.xlabel('sourceDate')
g=plt.ylabel('vader_weighted')  

plt.xticks(rotation=45)
# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 8))

plt.plot(wf_twitterDF['sourceDate'], wf_twitterDF['vader_weighted'], 'bo');
plt.xlabel('date', size = 18); plt.ylabel('vader compound weighted', size = 18); 
plt.title('range of vader compound weighted score per date', size = 20);
# Out:
# C:\Users\yulmee\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### 4.1.2 *Ordinary Least squares linear regression - without resampling*

# %%
wf_twitterDF['Intercept'] = 1
# Create the features and response
#X = wf_twitterDF.loc[:, ['Intercept', 'sourceDate']]
#y = wf_twitterDF.loc[:, 'vader_weighted']

X = wf_twitterDF.loc[:, ['Intercept', 'sourceDate','vader_weighted']]
y = wf_twitterDF.loc[:, 'Close']


wf_announced_date = datetime(2019, 9, 27,0,0,0)  
X['Timestamp'] = X.apply(lambda row: (row.sourceDate - wf_announced_date).days, axis = 1)

# %%
linear_regression = LinearRegression()
linear_regression.fit(np.array(X.Timestamp).reshape(-1,1),y)
y_pred = linear_regression.predict(X.Timestamp.values.astype(float).reshape(-1,1))
# df.time.values.astype(float).reshape(-1, 1)
print('Intercept from library:', linear_regression.intercept_)
print('Slope from library:', linear_regression.coef_[0])
wf_vader_intercept = linear_regression.intercept_
wf_vader_slope =  linear_regression.coef_[0]
# Notes: see 
# 1. https://scikit-learn.org/stable/auto_examples/linear_model/plot_ols.html
# 2. https://stackoverflow.com/questions/54352621/sklearn-linear-regression-with-date-data
# Out:
# Intercept from library: 50.668387530329525
# Slope from library: -0.2933188877125555

# %%
plt.figure(figsize=(8, 8)) 
plt.scatter(X.sourceDate, y,  color='black')
plt.plot(X.sourceDate, y_pred, color='blue', linewidth=3)
plt.xlabel('date', size = 18); plt.ylabel('Close price', size = 18); 
#plt.xticks(())
#plt.yticks(())

plt.show()

# %% [markdown]
# #### 4.1.3. Bayesian Linear regression - without resampling

# %%
wf_twitterDF.Close.describe()
# Out:
# count    270.000000
# mean      50.022000
# std        0.808853
# min       48.470001
# 25%       49.060001
# 50%       50.439999
# 75%       50.709999
# max       50.709999
# Name: Close, dtype: float64

# %%
# Using all observations (use mu=50 and sd=0.81 from dataframe statistics for vader compound score)

with pm.Model() as linear_model:
    # Intercept
    intercept = pm.Normal('Intercept', mu = 50, sd = 0.81)
    
    # Slope 
    slope = pm.Normal('slope', mu = 50, sd = 0.81)
    
    # Standard deviation
    sigma = pm.HalfNormal('sigma', sd = 0.81)
    
    # Estimate of mean
    mean = intercept + slope * X.loc[:, 'Timestamp']
    
    # Observed values
    Y_obs = pm.Normal('Y_obs', mu = mean, sd = sigma, observed = y.values)
    
    # Sampler
    step = pm.NUTS()

    # Posterior distribution
    linear_trace = pm.sample(1000, step)
# Out:
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, slope, Intercept]
# Sampling 2 chains, 0 divergences: 100%|████████████████████████████████████████| 3000/3000 [00:06<00:00, 435.84draws/s]
# The acceptance probability does not match the target. It is 0.9948017045869039, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9765790512278557, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
plt.figure(figsize = (8, 8))
pm.plot_posterior_predictive_glm(linear_trace, samples = 100, eval=np.linspace(2, 30, 100), linewidth = 1, 
                                 color = 'red', alpha = 0.8, label = 'Bayesian Posterior Fits',
                                lm = lambda x, sample: sample['Intercept'] + sample['slope'] * x);
plt.scatter(X['Timestamp'], y.values, s = 12, alpha = 0.8, c = 'blue', label = 'Observations')
plt.plot(X['Timestamp'], wf_vader_intercept + X['Timestamp'] * wf_vader_slope, 'k--', label = 'OLS Fit', linewidth = 1.4)
plt.title('Posterior Predictions with all Observations', size = 20); plt.xlabel('Timestamp', size = 18);
plt.ylabel('Stock price', size = 18);
plt.legend(prop={'size': 16});

# %% [markdown]
# ### 4.1.4 Ordinary Least squares linear regression - with resampling

# %%
wf_t_master_df.Close.describe()
# Out:
# count    3000.000000
# mean       49.468333
# std         0.821790
# min        48.470001
# 25%        48.869999
# 50%        49.159999
# 75%        50.439999
# max        50.709999
# Name: Close, dtype: float64

# %%
wf_t_master_df['Intercept'] = 1
# Create the features and response
X = wf_t_master_df.loc[:, ['Intercept', 'sourceDate','vader_weighted']]
y = wf_t_master_df.loc[:, 'Close']

wf_announced_date = datetime(2019, 9, 27,0,0,0)  
X['Timestamp'] = X.apply(lambda row: (row.sourceDate - wf_announced_date).days, axis = 1) 

linear_regression = LinearRegression()
linear_regression.fit(np.array(X.Timestamp).reshape(-1,1),y)
y_pred = linear_regression.predict(X.Timestamp.values.astype(float).reshape(-1,1))
# df.time.values.astype(float).reshape(-1, 1)
print('Intercept from library:', linear_regression.intercept_)
print('Slope from library:', linear_regression.coef_[0])
wf_vader_intercept = linear_regression.intercept_
wf_vader_slope =  linear_regression.coef_[0]
# Notes: see 
# 1. https://scikit-learn.org/stable/auto_examples/linear_model/plot_ols.html
# 2. https://stackoverflow.com/questions/54352621/sklearn-linear-regression-with-date-data

plt.figure(figsize=(8, 8)) 
plt.scatter(X.sourceDate, y,  color='black')
plt.plot(X.sourceDate, y_pred, color='blue', linewidth=3)
plt.xlabel('date', size = 18); plt.ylabel('stock price', size = 18); 
#plt.xticks(())
#plt.yticks(())

plt.show()
# Out:
# Intercept from library: 49.56574191164658
# Slope from library: -0.06493938554216822

# %% [markdown]
# #### 4.1.5. Bayesian Linear regression - with resampling

# %%
# Using all observations (use mu=49.47 and sd=0.82 from dataframe statistics for vader compound score)

with pm.Model() as linear_model:
    # Intercept
    intercept = pm.Normal('Intercept', mu = 49.47, sd = 0.82)
    
    # Slope 
    slope = pm.Normal('slope', mu = 49.47, sd = 0.82)
    
    # Standard deviation
    sigma = pm.HalfNormal('sigma', sd = 0.82)
    
    # Estimate of mean
    mean = intercept + slope * X.loc[:, 'Timestamp']
    
    # Observed values
    Y_obs = pm.Normal('Y_obs', mu = mean, sd = sigma, observed = y.values)
    
    # Sampler
    step = pm.NUTS(max_treedepth=12)#target_accept=0.90, 

    # Posterior distribution
    linear_trace = pm.sample(1000, step)
# Out:
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, slope, Intercept]
# Sampling 2 chains, 0 divergences: 100%|█████████████████████████████████████████| 3000/3000 [03:11<00:00, 15.70draws/s]
# The acceptance probability does not match the target. It is 0.9999902243726064, but should be close to 0.8. Try to increase the number of tuning steps.
# The chain reached the maximum tree depth. Increase max_treedepth, increase target_accept or reparameterize.
# The acceptance probability does not match the target. It is 0.999927860452597, but should be close to 0.8. Try to increase the number of tuning steps.
# The chain reached the maximum tree depth. Increase max_treedepth, increase target_accept or reparameterize.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
plt.figure(figsize = (8, 8))
pm.plot_posterior_predictive_glm(linear_trace, samples = 100, eval=np.linspace(2, 30, 100), linewidth = 1, 
                                 color = 'red', alpha = 0.8, label = 'Bayesian Posterior Fits',
                                lm = lambda x, sample: sample['Intercept'] + sample['slope'] * x);
plt.scatter(X['Timestamp'], y.values, s = 12, alpha = 0.8, c = 'blue', label = 'Observations')
plt.plot(X['Timestamp'], wf_vader_intercept + X['Timestamp'] * wf_vader_slope, 'k--', label = 'OLS Fit', linewidth = 1.4)
plt.title('Posterior Predictions with all Observations', size = 20); plt.xlabel('Timestamp', size = 18);
plt.ylabel('Stock price', size = 18);
plt.legend(prop={'size': 16});

# %% [markdown]
# ### 4.2. TB Polarity

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# Create box plot with Seaborn's default settings
g=sns.boxplot(x='sourceDate', y='tb_weighted', data=wf_twitterDF,  medianprops={'color':'red'}) #, showfliers=False)


# Label the axes
g=plt.xlabel('sourceDate')
g=plt.ylabel('TB Polarity weighted')  

plt.xticks(rotation=45)
# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 8))

plt.plot(wf_twitterDF['sourceDate'], wf_twitterDF['tb_weighted'], 'bo');
plt.xlabel('date', size = 18); plt.ylabel('vader compound weighted', size = 18); 
plt.title('range of TextBlob polarity weighted score per date', size = 20);

# %% [markdown]
# ### 4.2.2 Ordinary Least squares linear regression - without resampling

# %%
wf_twitterDF['Intercept'] = 1
# Create the features and response
X = wf_twitterDF.loc[:,  ['Intercept', 'sourceDate','tb_weighted']]
y = wf_twitterDF.loc[:, 'Close']

wf_announced_date = datetime(2019, 9, 27,0,0,0)  
X['Timestamp'] = X.apply(lambda row: (row.sourceDate - wf_announced_date).days, axis = 1) 

linear_regression = LinearRegression()
linear_regression.fit(np.array(X.Timestamp).reshape(-1,1),y)
y_pred = linear_regression.predict(X.Timestamp.values.astype(float).reshape(-1,1))
# df.time.values.astype(float).reshape(-1, 1)
print('Intercept from library:', linear_regression.intercept_)
print('Slope from library:', linear_regression.coef_[0])
wf_tb_intercept = linear_regression.intercept_
wf_tb_slope =  linear_regression.coef_[0]
# Notes: see 
# 1. https://scikit-learn.org/stable/auto_examples/linear_model/plot_ols.html
# 2. https://stackoverflow.com/questions/54352621/sklearn-linear-regression-with-date-data
# Out:
# Intercept from library: 50.668387530329525
# Slope from library: -0.2933188877125555

# %%
plt.figure(figsize=(8, 8)) 
plt.scatter(X.sourceDate, y,  color='black')
plt.plot(X.sourceDate, y_pred, color='blue', linewidth=3)
plt.xlabel('date', size = 18); plt.ylabel('Stock price', size = 18); 
#plt.xticks(())
#plt.yticks(())

plt.show()

# %% [markdown]
# ### 4.1.3. Bayesian Linear regression - without resampling

# %%
wf_twitterDF.Close.describe()
# Out:
# count    270.000000
# mean      50.022000
# std        0.808853
# min       48.470001
# 25%       49.060001
# 50%       50.439999
# 75%       50.709999
# max       50.709999
# Name: Close, dtype: float64

# %%
# Using all observations (use , mu = 0.06 and sd = 0.14 from dataframe statistics for tb polarity score)

with pm.Model() as linear_model:
    # Intercept
    intercept = pm.Normal('Intercept', mu = 50, sd = 0.81)
    
    # Slope 
    slope = pm.Normal('slope', mu = 50, sd = 0.81)
    
    # Standard deviation
    sigma = pm.HalfNormal('sigma', sd = 0.81)
    
    # Estimate of mean
    mean = intercept + slope * X.loc[:, 'Timestamp']
    
    # Observed values
    Y_obs = pm.Normal('Y_obs', mu = mean, sd = sigma, observed = y.values)
    
    # Sampler
    step = pm.NUTS()

    # Posterior distribution
    linear_trace = pm.sample(1000, step)
# Out:
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, slope, Intercept]
# Sampling 2 chains, 0 divergences: 100%|████████████████████████████████████████| 3000/3000 [00:06<00:00, 478.99draws/s]
# The acceptance probability does not match the target. It is 0.9812816382418452, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9687809447771422, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
plt.figure(figsize = (8, 8))
pm.plot_posterior_predictive_glm(linear_trace, samples = 100, eval=np.linspace(2, 30, 100), linewidth = 1, 
                                 color = 'red', alpha = 0.8, label = 'Bayesian Posterior Fits',
                                lm = lambda x, sample: sample['Intercept'] + sample['slope'] * x);
plt.scatter(X['Timestamp'], y.values, s = 12, alpha = 0.8, c = 'blue', label = 'Observations')
plt.plot(X['Timestamp'], wf_tb_intercept + X['Timestamp'] * wf_tb_slope, 'k--', label = 'OLS Fit', linewidth = 1.4)
plt.title('Posterior Predictions with all Observations', size = 20); plt.xlabel('Timestamp', size = 18);
plt.ylabel('Stock price', size = 18);
plt.legend(prop={'size': 16});

# %% [markdown]
# ### 4.2.4 Ordinary Least squares linear regression - with resampling

# %%
wf_t_master_df.Close.describe()
# Out:
# count    3000.000000
# mean       49.468333
# std         0.821790
# min        48.470001
# 25%        48.869999
# 50%        49.159999
# 75%        50.439999
# max        50.709999
# Name: Close, dtype: float64

# %%
wf_t_master_df['Intercept'] = 1
# Create the features and response
X = wf_t_master_df.loc[:, ['Intercept', 'sourceDate','tb_weighted']]
y = wf_t_master_df.loc[:, 'Close']

wf_announced_date = datetime(2019, 9, 27,0,0,0)  
X['Timestamp'] = X.apply(lambda row: (row.sourceDate - wf_announced_date).days, axis = 1) 

linear_regression = LinearRegression()
linear_regression.fit(np.array(X.Timestamp).reshape(-1,1),y)
y_pred = linear_regression.predict(X.Timestamp.values.astype(float).reshape(-1,1))
# df.time.values.astype(float).reshape(-1, 1)
print('Intercept from library:', linear_regression.intercept_)
print('Slope from library:', linear_regression.coef_[0])
wf_tb_intercept = linear_regression.intercept_
wf_tb_slope =  linear_regression.coef_[0]
# Notes: see 
# 1. https://scikit-learn.org/stable/auto_examples/linear_model/plot_ols.html
# 2. https://stackoverflow.com/questions/54352621/sklearn-linear-regression-with-date-data

plt.figure(figsize=(8, 8)) 
plt.scatter(X.sourceDate, y,  color='black')
plt.plot(X.sourceDate, y_pred, color='blue', linewidth=3)
plt.xlabel('date', size = 18); plt.ylabel('Stock price', size = 18); 
#plt.xticks(())
#plt.yticks(())

plt.show()
# Out:
# Intercept from library: 49.56574191164658
# Slope from library: -0.06493938554216822

# %% [markdown]
# ### 4.2.5. Bayesian Linear regression - with resampling

# %%
# Using all observations (use mu = 49.47, sd = 0.82 from dataframe statistics for tb polarity score)

with pm.Model() as linear_model:
    # Intercept
    intercept = pm.Normal('Intercept', mu = 49.47, sd = 00.82)
    
    # Slope 
    slope = pm.Normal('slope', mu = 49.47, sd = 0.82)
    
    # Standard deviation
    sigma = pm.HalfNormal('sigma', sd = 0.82)
    
    # Estimate of mean
    mean = intercept + slope * X.loc[:, 'Timestamp']
    
    # Observed values
    Y_obs = pm.Normal('Y_obs', mu = mean, sd = sigma, observed = y.values)
    
    # Sampler
    step = pm.NUTS(max_treedepth=12)

    # Posterior distribution
    linear_trace = pm.sample(1000, step)
# Out:
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, slope, Intercept]
# Sampling 2 chains, 1 divergences: 100%|█████████████████████████████████████████| 3000/3000 [03:48<00:00, 13.15draws/s]
# The acceptance probability does not match the target. It is 0.9999483337602413, but should be close to 0.8. Try to increase the number of tuning steps.
# The chain reached the maximum tree depth. Increase max_treedepth, increase target_accept or reparameterize.
# The acceptance probability does not match the target. It is 0.9999569235012085, but should be close to 0.8. Try to increase the number of tuning steps.
# The chain reached the maximum tree depth. Increase max_treedepth, increase target_accept or reparameterize.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
plt.figure(figsize = (8, 8))
pm.plot_posterior_predictive_glm(linear_trace, samples = 100, eval=np.linspace(2, 30, 100), linewidth = 1, 
                                 color = 'red', alpha = 0.8, label = 'Bayesian Posterior Fits',
                                lm = lambda x, sample: sample['Intercept'] + sample['slope'] * x);
plt.scatter(X['Timestamp'], y.values, s = 12, alpha = 0.8, c = 'blue', label = 'Observations')
plt.plot(X['Timestamp'], wf_tb_intercept + X['Timestamp'] * wf_tb_slope, 'k--', label = 'OLS Fit', linewidth = 1.4)
plt.title('Posterior Predictions with all Observations', size = 20); plt.xlabel('Timestamp', size = 18);
plt.ylabel('tb polarity weighted score', size = 18);
plt.legend(prop={'size': 16});

# %% [markdown]
# ## 5. SAP - Compare between dates

# %% [markdown]
# ### 5.1. Vader Compound

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# Create box plot with Seaborn's default settings
g=sns.boxplot(x='sourceDate', y='vader_weighted', data=sap_twitterDF, medianprops={'color':'red'})


# Label the axes
g=plt.xlabel('sourceDate')
g=plt.ylabel('vader_weighted')  

plt.xticks(rotation=45)
# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 8))

plt.plot(sap_twitterDF['sourceDate'], sap_twitterDF['vader_weighted'], 'bo');
plt.xlabel('date', size = 18); plt.ylabel('vader compound weighted', size = 18); 
plt.title('range of vader compound weighted score per date', size = 20);

# %%
sap_twitterDF['Close'].describe()
# Out:
# count    359.000000
# mean     123.436017
# std        5.230071
# min      115.250000
# 25%      115.250000
# 50%      126.199997
# 75%      127.180000
# max      128.720001
# Name: Close, dtype: float64

# %% [markdown]
# ### 5.1.1 Ordinary Least squares linear regression - without resampling

# %%
sap_twitterDF['Intercept'] = 1
# Create the features and response
X = sap_twitterDF.loc[:, ['Intercept', 'sourceDate','vader_compound']]
y = sap_twitterDF.loc[:, 'Close']

sap_announced_date = datetime(2019, 10, 10,0,0,0)  

X['Timestamp'] = X.apply(lambda row: (row.sourceDate - sap_announced_date).days, axis = 1) 

linear_regression = LinearRegression()
linear_regression.fit(np.array(X.Timestamp).reshape(-1,1),y)
y_pred = linear_regression.predict(X.Timestamp.values.astype(float).reshape(-1,1))
# df.time.values.astype(float).reshape(-1, 1)
print('Intercept from library:', linear_regression.intercept_)
print('Slope from library:', linear_regression.coef_[0])
sap_vader_intercept = linear_regression.intercept_
sap_vader_slope =  linear_regression.coef_[0]


plt.figure(figsize=(8, 8)) 
plt.scatter(X.sourceDate, y,  color='black')
plt.plot(X.sourceDate, y_pred, color='blue', linewidth=3)
plt.xlabel('date', size = 18); plt.ylabel('vader compound', size = 18); 
#plt.xticks(())
#plt.yticks(())

plt.show()
# Out:
# Intercept from library: 119.22661890179646
# Slope from library: 1.7510704012225644

# %% [markdown]
# ### 5.1.2. Bayesian Linear regression - without resampling

# %%
# Using all observations (use mu=123.44 and sd=5.23 from dataframe statistics for vader compound score)


with pm.Model() as linear_model:
    # Intercept
    intercept = pm.Normal('Intercept', mu = 123.44, sd = 5.23)
    
    # Slope 
    slope = pm.Normal('slope', mu = 123.44, sd = 5.23)
    
    # Standard deviation
    sigma = pm.HalfNormal('sigma', sd = 5.23)
    
    # Estimate of mean
    mean = intercept + slope * X.loc[:, 'Timestamp']
    
    # Observed values
    Y_obs = pm.Normal('Y_obs', mu = mean, sd = sigma, observed = y.values)
    
    # Sampler
    step = pm.NUTS()

    # Posterior distribution
    linear_trace = pm.sample(1000, step)
# Out:
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, slope, Intercept]
# Sampling 2 chains, 0 divergences: 100%|████████████████████████████████████████| 3000/3000 [00:05<00:00, 502.16draws/s]
# The acceptance probability does not match the target. It is 0.9177241722436693, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9237400049747895, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
plt.figure(figsize = (8, 8))
pm.plot_posterior_predictive_glm(linear_trace, samples = 100, eval=np.linspace(2, 30, 100), linewidth = 1, 
                                 color = 'red', alpha = 0.8, label = 'Bayesian Posterior Fits',
                                lm = lambda x, sample: sample['Intercept'] + sample['slope'] * x);
plt.scatter(X['Timestamp'], y.values, s = 12, alpha = 0.8, c = 'blue', label = 'Observations')
plt.plot(X['Timestamp'], sap_vader_intercept + X['Timestamp'] * sap_vader_slope, 'k--', label = 'OLS Fit', linewidth = 1.4)
plt.title('Posterior Predictions with all Observations', size = 20); plt.xlabel('Timestamp', size = 18);
plt.ylabel('Stock Price', size = 18);
plt.legend(prop={'size': 16});

# %% [markdown]
# ### 5.1.3 Ordinary Least squares linear regression - with resampling

# %%
sap_t_master_df.Close.describe()
# Out:
# count    3000.000000
# mean      123.241667
# std         5.443760
# min       115.250000
# 25%       116.050003
# 50%       126.125000
# 75%       127.180000
# max       128.720001
# Name: Close, dtype: float64

# %%
sap_t_master_df['Intercept'] = 1
# Create the features and response
X = sap_t_master_df.loc[:, ['Intercept', 'sourceDate','vader_weighted']]
y = sap_t_master_df.loc[:, 'Close']

sap_announced_date = datetime(2019, 10, 10,0,0,0)  
X['Timestamp'] = X.apply(lambda row: (row.sourceDate - sap_announced_date).days, axis = 1) 

linear_regression = LinearRegression()
linear_regression.fit(np.array(X.Timestamp).reshape(-1,1),y)
y_pred = linear_regression.predict(X.Timestamp.values.astype(float).reshape(-1,1))
# df.time.values.astype(float).reshape(-1, 1)
print('Intercept from library:', linear_regression.intercept_)
print('Slope from library:', linear_regression.coef_[0])
sap_vader_intercept = linear_regression.intercept_
sap_vader_slope =  linear_regression.coef_[0]
# Notes: see 
# 1. https://scikit-learn.org/stable/auto_examples/linear_model/plot_ols.html
# 2. https://stackoverflow.com/questions/54352621/sklearn-linear-regression-with-date-data

plt.figure(figsize=(8, 8)) 
plt.scatter(X.sourceDate, y,  color='black')
plt.plot(X.sourceDate, y_pred, color='blue', linewidth=3)
plt.xlabel('date', size = 18); plt.ylabel('Stock Price', size = 18); 
#plt.xticks(())
#plt.yticks(())

plt.show()
# Out:
# Intercept from library: 118.78714914056225
# Slope from library: 1.7818072771084288

# %% [markdown]
# ### 5.1.4. Bayesian Linear regression - with resampling

# %%
# Using all observations (use mu= 123.24 and sd=5.44 from dataframe statistics for vader compound score)

with pm.Model() as linear_model:
    # Intercept
    intercept = pm.Normal('Intercept', mu = 123.24, sd = 5.44)
    
    # Slope 
    slope = pm.Normal('slope', mu = 123.24, sd = 5.44)
    
    # Standard deviation
    sigma = pm.HalfNormal('sigma', sd = 5.44)
    
    # Estimate of mean
    mean = intercept + slope * X.loc[:, 'Timestamp']
    
    # Observed values
    Y_obs = pm.Normal('Y_obs', mu = mean, sd = sigma, observed = y.values)
    
    # Sampler
    step = pm.NUTS()

    # Posterior distribution
    linear_trace = pm.sample(1000, step)
# Out:
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, slope, Intercept]
# Sampling 2 chains, 0 divergences: 100%|████████████████████████████████████████| 3000/3000 [00:15<00:00, 199.38draws/s]
# The acceptance probability does not match the target. It is 0.9946286635197822, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9959295302235724, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
plt.figure(figsize = (8, 8))
pm.plot_posterior_predictive_glm(linear_trace, samples = 100, eval=np.linspace(2, 30, 100), linewidth = 1, 
                                 color = 'red', alpha = 0.8, label = 'Bayesian Posterior Fits',
                                lm = lambda x, sample: sample['Intercept'] + sample['slope'] * x);
plt.scatter(X['Timestamp'], y.values, s = 12, alpha = 0.8, c = 'blue', label = 'Observations')
plt.plot(X['Timestamp'], sap_vader_intercept + X['Timestamp'] * sap_vader_slope, 'k--', label = 'OLS Fit', linewidth = 1.4)
plt.title('Posterior Predictions with all Observations', size = 20); plt.xlabel('Timestamp', size = 18);
plt.ylabel('Stock Price', size = 18);
plt.legend(prop={'size': 16});

# %% [markdown]
# ### 5.2. TextBlob Polarity

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# Create box plot with Seaborn's default settings
g=sns.boxplot(x='sourceDate', y='tb_weighted', data=sap_twitterDF, medianprops={'color':'red'})


# Label the axes
g=plt.xlabel('sourceDate')
g=plt.ylabel('tb polarity weighted')  

plt.xticks(rotation=45)
# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 8))

plt.plot(sap_twitterDF['sourceDate'], sap_twitterDF['tb_weighted'], 'bo');
plt.xlabel('date', size = 18); plt.ylabel('TextBlob polarity weighted', size = 18); 
plt.title('range of TextBlob Polarity weighted score per date', size = 20);

# %% [markdown]
# ### 5.2.2 Ordinary Least squares linear regression - without resampling

# %%
sap_twitterDF['Intercept'] = 1
# Create the features and response
X = sap_twitterDF.loc[:, ['Intercept', 'sourceDate','tb_weighted']]
y = sap_twitterDF.loc[:, 'Close']

sap_announced_date = datetime(2019, 10, 10,0,0,0)  
X['Timestamp'] = X.apply(lambda row: (row.sourceDate - sap_announced_date).days, axis = 1) 

linear_regression = LinearRegression()
linear_regression.fit(np.array(X.Timestamp).reshape(-1,1),y)
y_pred = linear_regression.predict(X.Timestamp.values.astype(float).reshape(-1,1))
# df.time.values.astype(float).reshape(-1, 1)
print('Intercept from library:', linear_regression.intercept_)
print('Slope from library:', linear_regression.coef_[0])
sap_tb_intercept = linear_regression.intercept_
sap_tb_slope =  linear_regression.coef_[0]
# Out:
# Intercept from library: 119.22661890179646
# Slope from library: 1.7510704012225644

# %%
plt.figure(figsize=(8, 8)) 
plt.scatter(X.sourceDate, y,  color='black')
plt.plot(X.sourceDate, y_pred, color='blue', linewidth=3)
plt.xlabel('date', size = 18); plt.ylabel('Stock Price', size = 18); 
#plt.xticks(())
#plt.yticks(())

plt.show()

# %% [markdown]
# ### 5.2.3. Bayesian Linear regression - without resampling

# %%
sap_twitterDF.Close.describe()
# Out:
# count    359.000000
# mean     123.436017
# std        5.230071
# min      115.250000
# 25%      115.250000
# 50%      126.199997
# 75%      127.180000
# max      128.720001
# Name: Close, dtype: float64

# %%
# Using all observations (use , mu = 123.44 and sd = 5.23 from dataframe statistics for tb polarity score)

with pm.Model() as linear_model:
    # Intercept
    intercept = pm.Normal('Intercept', mu = 123.44, sd = 5.23)
    
    # Slope 
    slope = pm.Normal('slope', mu = 123.44, sd = 5.23)
    
    # Standard deviation
    sigma = pm.HalfNormal('sigma', sd = 5.23)
    
    # Estimate of mean
    mean = intercept + slope * X.loc[:, 'Timestamp']
    
    # Observed values
    Y_obs = pm.Normal('Y_obs', mu = mean, sd = sigma, observed = y.values)
    
    # Sampler
    step = pm.NUTS()

    # Posterior distribution
    linear_trace = pm.sample(1000, step)
# Out:
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, slope, Intercept]
# Sampling 2 chains, 0 divergences: 100%|████████████████████████████████████████| 3000/3000 [00:06<00:00, 446.63draws/s]
# The acceptance probability does not match the target. It is 0.9371942400786571, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.892802741991747, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
plt.figure(figsize = (8, 8))
pm.plot_posterior_predictive_glm(linear_trace, samples = 100, eval=np.linspace(2, 30, 100), linewidth = 1, 
                                 color = 'red', alpha = 0.8, label = 'Bayesian Posterior Fits',
                                lm = lambda x, sample: sample['Intercept'] + sample['slope'] * x);
plt.scatter(X['Timestamp'], y.values, s = 12, alpha = 0.8, c = 'blue', label = 'Observations')
plt.plot(X['Timestamp'], sap_tb_intercept + X['Timestamp'] * sap_tb_slope, 'k--', label = 'OLS Fit', linewidth = 1.4)
plt.title('Posterior Predictions with all Observations', size = 20); plt.xlabel('Timestamp', size = 18);
plt.ylabel('Stpck Price', size = 18);
plt.legend(prop={'size': 16});

# %% [markdown]
# ### 5.2.4 Ordinary Least squares linear regression - with resampling

# %%
sap_t_master_df.Close.describe()
# Out:
# count    3000.000000
# mean      123.241667
# std         5.443760
# min       115.250000
# 25%       116.050003
# 50%       126.125000
# 75%       127.180000
# max       128.720001
# Name: Close, dtype: float64

# %%
sap_t_master_df['Intercept'] = 1
# Create the features and response
X = sap_t_master_df.loc[:, ['Intercept', 'sourceDate','tb_weighted']]
y = sap_t_master_df.loc[:, 'Close']

sap_announced_date = datetime(2019, 10, 10,0,0,0)  
X['Timestamp'] = X.apply(lambda row: (row.sourceDate - sap_announced_date).days, axis = 1) 

linear_regression = LinearRegression()
linear_regression.fit(np.array(X.Timestamp).reshape(-1,1),y)
y_pred = linear_regression.predict(X.Timestamp.values.astype(float).reshape(-1,1))
# df.time.values.astype(float).reshape(-1, 1)
print('Intercept from library:', linear_regression.intercept_)
print('Slope from library:', linear_regression.coef_[0])
sap_tb_intercept = linear_regression.intercept_
sap_tb_slope =  linear_regression.coef_[0]
# Notes: see 
# 1. https://scikit-learn.org/stable/auto_examples/linear_model/plot_ols.html
# 2. https://stackoverflow.com/questions/54352621/sklearn-linear-regression-with-date-data

plt.figure(figsize=(8, 8)) 
plt.scatter(X.sourceDate, y,  color='black')
plt.plot(X.sourceDate, y_pred, color='blue', linewidth=3)
plt.xlabel('date', size = 18); plt.ylabel('Stock Price', size = 18); 
#plt.xticks(())
#plt.yticks(())

plt.show()
# Out:
# Intercept from library: 118.78714914056225
# Slope from library: 1.7818072771084288

# %% [markdown]
# ### 4.2.5. Bayesian Linear regression - with resampling

# %%
# Using all observations (use mu =123.24, sd = 5.44 from dataframe statistics for tb polarity score)

with pm.Model() as linear_model:
    # Intercept
    intercept = pm.Normal('Intercept', mu = 123.24, sd = 5.44)
    
    # Slope 
    slope = pm.Normal('slope', mu = 123.24, sd = 5.44)
    
    # Standard deviation
    sigma = pm.HalfNormal('sigma', sd = 5.44)
    
    # Estimate of mean
    mean = intercept + slope * X.loc[:, 'Timestamp']
    
    # Observed values
    Y_obs = pm.Normal('Y_obs', mu = mean, sd = sigma, observed = y.values)
    
    # Sampler
    step = pm.NUTS()

    # Posterior distribution
    linear_trace = pm.sample(1000, step)
# Out:
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, slope, Intercept]
# Sampling 2 chains, 0 divergences: 100%|█████████████████████████████████████████| 3000/3000 [01:34<00:00, 12.29draws/s]
# The chain reached the maximum tree depth. Increase max_treedepth, increase target_accept or reparameterize.
# The acceptance probability does not match the target. It is 0.9516594111821434, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
plt.figure(figsize = (8, 8))
pm.plot_posterior_predictive_glm(linear_trace, samples = 100, eval=np.linspace(2, 30, 100), linewidth = 1, 
                                 color = 'red', alpha = 0.8, label = 'Bayesian Posterior Fits',
                                lm = lambda x, sample: sample['Intercept'] + sample['slope'] * x);
plt.scatter(X['Timestamp'], y.values, s = 12, alpha = 0.8, c = 'blue', label = 'Observations')
plt.plot(X['Timestamp'], sap_tb_intercept + X['Timestamp'] * sap_tb_slope, 'k--', label = 'OLS Fit', linewidth = 1.4)
plt.title('Posterior Predictions with all Observations', size = 20); plt.xlabel('Timestamp', size = 18);
plt.ylabel('Stock Price', size = 18);
plt.legend(prop={'size': 16});
