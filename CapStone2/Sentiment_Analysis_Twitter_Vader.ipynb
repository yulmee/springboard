# %%
from pymongo import MongoClient
import pymongo
import json
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import timedelta

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## 1. Populate Dataframes

# %%
# read from csv files
 
topicsDF = pd.read_csv(r'topics.csv',encoding='latin-1')

twitterDF = pd.read_csv(r'twitter.csv',encoding='latin-1')

# %%
# Total number for each company
wf_twitterDF= twitterDF[(twitterDF.source == 'WF') & (twitterDF.isRelated=='Y')]
print("WF Twits: "+ str(wf_twitterDF.size))

sap_twitterDF = twitterDF[(twitterDF.source == 'SAP') & (twitterDF.isRelated=='Y')]
print("SAP Twits: "+ str(sap_twitterDF.size))

ww_twitterDF = twitterDF[(twitterDF.source == 'WW') & (twitterDF.isRelated=='Y')]
print("WeWork Twits: "+ str(ww_twitterDF.size))
# Out:
# WF Twits: 8760
# SAP Twits: 10480
# WeWork Twits: 980

# %%
wf_twitterDF.head()
# Out:
#    Unnamed: 0                        id  \
# 0           0  5dab73ca11bb5a1f6c86dfbd
# 1           1  5dab73cb11bb5a1f6c86dfbe
# 2           2  5dab73cb11bb5a1f6c86dfbf
# 3           3  5dab73cb11bb5a1f6c86dfc0
# 4           4  5dab73cb11bb5a1f6c86dfc1
#
#                                                 text                      URL  \
# 0  Wells Fargo names outsider as new CEO three ye...  https://t.co/WBtIAtX8Gf
# 1  Wells Fargo names outsider as new CEO three ye...  https://t.co/veyphufgzw
# 2  Charles Scharf as CEO Can Revive Wells Fargo. ...  https://t.co/7q3CanBgNk
# 3  Wells Fargo Finally Appoints New CEO Who Is A ...  https://t.co/cghUhYeY8U
# 4  Wells Fargo gives new CEO a 40% pay boost to $...  https://t.co/1Dl0uMQxzV
#
#       createdTimestamp  quoteCount  replyCount  retweetCount  favoriteCount  \
# 0  2019-09-27 23:51:00           2           0             0              0
# 1  2019-09-27 23:47:53           0           0             0              0
# 2  2019-09-27 23:39:53           0           0             0              0
# 3  2019-09-27 23:39:38           0           0             0              0
# 4  2019-09-27 23:37:41           0           0             1              0
#
#    isInReplyTouser_id         userLocation  userFollowersCount  \
# 0                 NaN                  NaN                4018
# 1                 NaN                  NaN                   4
# 2                 NaN  New York, New York                 2045
# 3                 NaN                  NaN                 237
# 4                 NaN    Orange County, CA              212542
#
#    userFriendsCount lang isRelated source  sourceDate   NP  isInReplyTo  \
# 0              3918   en         Y     WF  2019-09-27  NaN          0.0
# 1                 1   en         Y     WF  2019-09-27  NaN          0.0
# 2              1023   en         Y     WF  2019-09-27  NaN          0.0
# 3               367   en         Y     WF  2019-09-27  NaN          0.0
# 4              2481   en         Y     WF  2019-09-27  NaN          0.0
#
#         user_id
# 0  4.867858e+09
# 1  1.088562e+18
# 2  1.164775e+18
# 3  8.356552e+17
# 4  1.782049e+07

# %% [markdown]
# ## 2. Run through Vader Sentiment - WF

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
def get_sentiment_score (row):
    compound=np.nan
    if row['text'] is not None:
        analyzer = SentimentIntensityAnalyzer()
        vs = analyzer.polarity_scores(row['text'])
        compound=vs['compound']
    return compound

def set_sentiment (row):
    #1. positive sentiment: compound score >= 0.50
    #2. neutral sentiment: (compound score > -0.50) and (compound score < 0.50)
    #3. negative sentiment: compound score <= -0.50
    sentiment= 'E' # Neutral
    upper_limit = 0.50
    lower_limit = -0.50
    if (row['vader_compound'] >= upper_limit):
        sentiment = 'P' # Positive
    elif (row['vader_compound'] <= lower_limit):
        sentiment = 'N' # Negative
        
    return sentiment

# %%
# https://stackoverflow.com/questions/26886653/pandas-create-new-column-based-on-values-from-other-columns-apply-a-function-o

wf_twitterDF['vader_compound'] = wf_twitterDF.apply (lambda row: get_sentiment_score(row), axis=1)
# Out:
# C:\Users\yulmee\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
wf_twitterDF['vader_sentiment'] = wf_twitterDF.apply (lambda row: set_sentiment(row), axis=1)
# Out:
# C:\Users\yulmee\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
wf_twitterDF.head()
# Out:
#    Unnamed: 0                        id  \
# 0           0  5dab73ca11bb5a1f6c86dfbd
# 1           1  5dab73cb11bb5a1f6c86dfbe
# 2           2  5dab73cb11bb5a1f6c86dfbf
# 3           3  5dab73cb11bb5a1f6c86dfc0
# 4           4  5dab73cb11bb5a1f6c86dfc1
#
#                                                 text                      URL  \
# 0  Wells Fargo names outsider as new CEO three ye...  https://t.co/WBtIAtX8Gf
# 1  Wells Fargo names outsider as new CEO three ye...  https://t.co/veyphufgzw
# 2  Charles Scharf as CEO Can Revive Wells Fargo. ...  https://t.co/7q3CanBgNk
# 3  Wells Fargo Finally Appoints New CEO Who Is A ...  https://t.co/cghUhYeY8U
# 4  Wells Fargo gives new CEO a 40% pay boost to $...  https://t.co/1Dl0uMQxzV
#
#       createdTimestamp  quoteCount  replyCount  retweetCount  favoriteCount  \
# 0  2019-09-27 23:51:00           2           0             0              0
# 1  2019-09-27 23:47:53           0           0             0              0
# 2  2019-09-27 23:39:53           0           0             0              0
# 3  2019-09-27 23:39:38           0           0             0              0
# 4  2019-09-27 23:37:41           0           0             1              0
#
#    isInReplyTouser_id  ... userFriendsCount  lang  isRelated source  \
# 0                 NaN  ...             3918    en          Y     WF
# 1                 NaN  ...                1    en          Y     WF
# 2                 NaN  ...             1023    en          Y     WF
# 3                 NaN  ...              367    en          Y     WF
# 4                 NaN  ...             2481    en          Y     WF
#
#    sourceDate   NP isInReplyTo       user_id  vader_compound  vader_sentiment
# 0  2019-09-27  NaN         0.0  4.867858e+09         -0.6124                N
# 1  2019-09-27  NaN         0.0  1.088562e+18          0.2500                E
# 2  2019-09-27  NaN         0.0  1.164775e+18          0.5267                P
# 3  2019-09-27  NaN         0.0  8.356552e+17          0.2500                E
# 4  2019-09-27  NaN         0.0  1.782049e+07          0.5106                P
#
# [5 rows x 22 columns]

# %%
# Save to csv for future analysis
wf_twitterDF.to_csv('twitter_wf_vader.csv')

# %% [markdown]
# ## 3. Run through Vader Sentiment - SAP

# %%
sap_twitterDF['vader_compound'] = sap_twitterDF.apply (lambda row: get_sentiment_score(row), axis=1)
# Out:
# C:\Users\yulmee\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sap_twitterDF['vader_sentiment'] = sap_twitterDF.apply (lambda row: set_sentiment(row), axis=1)
# Out:
# C:\Users\yulmee\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sap_twitterDF.head()
# Out:
#      Unnamed: 0                        id  \
# 619         619  5dae77e811bb5a25b069085e
# 621         621  5dae77e811bb5a25b0690860
# 633         633  5dae77e911bb5a25b069086c
# 643         643  5dae77e911bb5a25b0690876
# 645         645  5dae784011bb5a25b0690878
#
#                                                   text  \
# 619  Experience Management: "Start with empathy for...
# 621  Experience Management: "Start with empathy for...
# 633  SAP CEO  has made clear: the new economy is he...
# 643  Thanks  for hosting Bill Mcdermott CEO of SAP ...
# 645  New article: "SAP CEO Bill McDermott stepping ...
#
#                          URL     createdTimestamp  quoteCount  replyCount  \
# 619                      NaN  2019-10-09 18:10:03           0           0
# 621  https://t.co/t0MxMZ5DxI  2019-10-09 18:00:01           0           0
# 633  https://t.co/tqPgEZix2U  2019-10-09 14:36:00           0           0
# 643                      NaN  2019-10-09 05:21:42           0           0
# 645  https://t.co/DoQvIY7sVy  2019-10-10 23:58:48           0           0
#
#      retweetCount  favoriteCount  isInReplyTouser_id  ... userFriendsCount  \
# 619             0              0                 NaN  ...             3925
# 621             2              5                 NaN  ...             3914
# 633             0              0                 NaN  ...             2169
# 643             0              1                 NaN  ...              319
# 645             0              1                 NaN  ...              279
#
#      lang  isRelated source  sourceDate   NP isInReplyTo       user_id  \
# 619    en          Y    SAP  2019-10-09  NaN         0.0  2.593419e+08
# 621    en          Y    SAP  2019-10-09  NaN         0.0  3.266873e+08
# 633    en          Y    SAP  2019-10-09  NaN         0.0  1.105129e+08
# 643    en          Y    SAP  2019-10-09  NaN         0.0  1.024890e+18
# 645    en          Y    SAP  2019-10-10  NaN         0.0  7.297547e+17
#
#      vader_compound  vader_sentiment
# 619          0.0000                E
# 621          0.0000                E
# 633          0.1027                E
# 643          0.7184                P
# 645          0.0000                E
#
# [5 rows x 22 columns]

# %%
# Save to csv for future analysis
sap_twitterDF.to_csv('twitter_sap_vader.csv')
